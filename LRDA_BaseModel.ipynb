# %% [markdown]
# ## Business Problem:
#
# **AIM:** _To reduce the risk of loan defaults, which can result in significant financial losses to the financial institutions. By detecting potential default risks early, lenders can take proactive measures to minimize the risk of default and protect their investments._

# %% [markdown]
# !pip install missingno

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
import plotly.express as px

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
from matplotlib import rcParams
plt.rcParams['figure.figsize'] = (15, 8)

from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Supervised Learning Classification Problem-
#    - **Target:**
#            Charged Off = 1
#            Current = 0

# %% [markdown]
# ### Read the dataset:

# %%
df_loan = pd.read_csv('Loan Risk Detector.csv')
df_loan.head(3)
# Out:
#          id  member_id  loan_amnt  funded_amnt        term  int_rate  \
# 0  60516983   64537751      20000        20000   36 months     12.29
# 1  60187139   64163931      11000        11000   36 months     12.69
# 2  60356453   64333218       7000         7000   36 months      9.99
#
#    installment grade sub_grade              emp_title emp_length  \
# 0       667.06     C        C1       Accounting Clerk     1 year
# 1       369.00     C        C2  Accounts Payable Lead    7 years
# 2       225.84     B        B3                  Nurse    6 years
#
#   home_ownership  annual_inc verification_status issue_d  loan_status  \
# 0            OWN     65000.0     Source Verified  Sep-15  Charged Off
# 1       MORTGAGE     40000.0     Source Verified  Sep-15  Charged Off
# 2       MORTGAGE     32000.0     Source Verified  Sep-15  Charged Off
#
#               purpose               title    dti  delinq_2yrs  \
# 0  debt_consolidation  Debt consolidation  20.72            0
# 1  debt_consolidation  Debt consolidation  24.57            0
# 2  debt_consolidation  Debt consolidation  32.41            0
#
#   earliest_cr_line  inq_last_6mths  mths_since_last_delinq  open_acc  pub_rec  \
# 0           Sep-00               1                     NaN        25        0
# 1           Sep-02               0                    36.0        13        1
# 2           Feb-06               1                     NaN        18        0
#
#    revol_bal  revol_util  total_acc initial_list_status  out_prncp  \
# 0      31578        77.0         42                   w        0.0
# 1       5084        38.8         41                   w        0.0
# 2      12070        74.0         36                   f        0.0
#
#    total_pymnt  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 0         0.00             0.00           0.00                 0.0
# 1     10043.49          9942.67         100.81                 0.0
# 2       221.96           167.56          54.40                 0.0
#
#    recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt  \
# 0         0.0                      0.0          NaN             0.00
# 1         0.0                      0.0       Oct-15         10059.00
# 2         0.0                      0.0       Oct-15           225.84
#
#   next_pymnt_d last_credit_pull_d  collections_12_mths_ex_med  \
# 0          NaN             Jan-16                           0
# 1          NaN             Jan-16                           0
# 2          NaN             Jan-16                           0
#
#    mths_since_last_major_derog application_type  annual_inc_joint  dti_joint  \
# 0                          NaN       INDIVIDUAL               NaN        NaN
# 1                         79.0       INDIVIDUAL               NaN        NaN
# 2                          NaN       INDIVIDUAL               NaN        NaN
#
#    acc_now_delinq  tot_coll_amt  tot_cur_bal  total_rev_hi_lim
# 0               0             0        52303             41000
# 1               0           332       175731             13100
# 2               0             0       202012             16300

# %%
msno.matrix(df_loan, label_rotation=90)
plt.show()

# %%
loan = df_loan.copy(deep=True)

# %% [markdown]
# ### Check size and datatypes:

# %%
df_loan.shape
# Out:
# (212999, 49)

# %% [markdown]
# **Interpretation:**
# - The data has 212999 observations and 49 attributes.
#     - We created a copy of original dataset for further EDA.

# %%
df_loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212999 entries, 0 to 212998
# Data columns (total 49 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   id                           212999 non-null  int64
#  1   member_id                    212999 non-null  int64
#  2   loan_amnt                    212999 non-null  int64
#  3   funded_amnt                  212999 non-null  int64
#  4   term                         212999 non-null  object
#  5   int_rate                     212999 non-null  float64
#  6   installment                  212999 non-null  float64
#  7   grade                        212999 non-null  object
#  8   sub_grade                    212999 non-null  object
#  9   emp_title                    200209 non-null  object
#  10  emp_length                   200232 non-null  object
#  11  home_ownership               212999 non-null  object
#  12  annual_inc                   212999 non-null  float64
#  13  verification_status          212999 non-null  object
#  14  issue_d                      212999 non-null  object
#  15  loan_status                  212999 non-null  object
#  16  purpose                      212999 non-null  object
#  17  title                        212984 non-null  object
#  18  dti                          212999 non-null  float64
#  19  delinq_2yrs                  212999 non-null  int64
#  20  earliest_cr_line             212999 non-null  object
#  21  inq_last_6mths               212999 non-null  int64
#  22  mths_since_last_delinq       109628 non-null  float64
#  23  open_acc                     212999 non-null  int64
#  24  pub_rec                      212999 non-null  int64
#  25  revol_bal                    212999 non-null  int64
#  26  revol_util                   212917 non-null  float64
#  27  total_acc                    212999 non-null  int64
#  28  initial_list_status          212999 non-null  object
#  29  out_prncp                    212999 non-null  float64
#  30  total_pymnt                  212999 non-null  float64
#  31  total_rec_prncp              212999 non-null  float64
#  32  total_rec_int                212999 non-null  float64
#  33  total_rec_late_fee           212999 non-null  float64
#  34  recoveries                   212999 non-null  float64
#  35  collection_recovery_fee      212999 non-null  float64
#  36  last_pymnt_d                 204510 non-null  object
#  37  last_pymnt_amnt              212999 non-null  float64
#  38  next_pymnt_d                 210226 non-null  object
#  39  last_credit_pull_d           212992 non-null  object
#  40  collections_12_mths_ex_med   212999 non-null  int64
#  41  mths_since_last_major_derog  62365 non-null   float64
#  42  application_type             212999 non-null  object
#  43  annual_inc_joint             441 non-null     float64
#  44  dti_joint                    439 non-null     float64
#  45  acc_now_delinq               212999 non-null  int64
#  46  tot_coll_amt                 212999 non-null  int64
#  47  tot_cur_bal                  212999 non-null  int64
#  48  total_rev_hi_lim             212999 non-null  int64
# dtypes: float64(17), int64(15), object(17)
# memory usage: 79.6+ MB

# %% [markdown]
# **Interpretation:**
# - There are 17 float, 15 int and 17 object values.
#
# - **The variables** `id`, `member_id`, `loan_amnt`, `funded_amnt`, `int_rate`, `installment`, `annual_inc`, `dti`, `delinq_2yrs`, `inq_last_6mths`, `mths_since_last_delinq`, `open_acc`, `pub_rec`, `revol_bal`, `revol_util`, `total_acc`, `out_prncp`, `total_pymnt`, `total_rec_prncp`, `total_rec_int`, `total_rec_late_fee`, `recoveries`, `collection_recovery_fee`, `last_pymnt_amnt`, `collections_12_mths_ex_med`, `mths_since_last_major_derog`, `annual_inc_joint`, `dti_joint`, `acc_now_delinq`, `tot_coll_amt`, `tot_cur_bal`, `total_rev_hi_lim` are **numerical**.
#
# - **The variables** `term`, `grade`, `sub_grade`, `emp_title`, `emp_length`, `home_ownership`, `verification_status`, `issue_d`, `loan_status`, `purpose`, `title`, `earliest_cr_line`, `initial_list_status`, `last_pymnt_d`, `next_pymnt_d`, `last_credit_pull_d`, `application_type` are **objects**.

# %% [markdown]
# ### Drop duplicate records:

# %%
loan.duplicated().value_counts()
# Out:
# False    212999
# dtype: int64

# %% [markdown]
# - There are **no duplicate records** in our dataset.

# %% [markdown]
# ### Drop Insignificant Features based on Domain Knowledge:

# %%
loan.drop(columns=['id','member_id','loan_amnt','sub_grade','emp_title','emp_length','verification_status','issue_d','purpose','title','mths_since_last_delinq','initial_list_status','last_pymnt_d','next_pymnt_d','last_credit_pull_d','mths_since_last_major_derog','application_type','annual_inc_joint','dti_joint','total_acc','collections_12_mths_ex_med'], inplace=True)

# %%
loan.shape
# Out:
# (212999, 28)

# %% [markdown]
# **Interpretation:**
#
# The above variables are redundant for further analysis. Thus, we drop those columns.

# %%
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212999 entries, 0 to 212998
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   funded_amnt              212999 non-null  int64
#  1   term                     212999 non-null  object
#  2   int_rate                 212999 non-null  float64
#  3   installment              212999 non-null  float64
#  4   grade                    212999 non-null  object
#  5   home_ownership           212999 non-null  object
#  6   annual_inc               212999 non-null  float64
#  7   loan_status              212999 non-null  object
#  8   dti                      212999 non-null  float64
#  9   delinq_2yrs              212999 non-null  int64
#  10  earliest_cr_line         212999 non-null  object
#  11  inq_last_6mths           212999 non-null  int64
#  12  open_acc                 212999 non-null  int64
#  13  pub_rec                  212999 non-null  int64
#  14  revol_bal                212999 non-null  int64
#  15  revol_util               212917 non-null  float64
#  16  out_prncp                212999 non-null  float64
#  17  total_pymnt              212999 non-null  float64
#  18  total_rec_prncp          212999 non-null  float64
#  19  total_rec_int            212999 non-null  float64
#  20  total_rec_late_fee       212999 non-null  float64
#  21  recoveries               212999 non-null  float64
#  22  collection_recovery_fee  212999 non-null  float64
#  23  last_pymnt_amnt          212999 non-null  float64
#  24  acc_now_delinq           212999 non-null  int64
#  25  tot_coll_amt             212999 non-null  int64
#  26  tot_cur_bal              212999 non-null  int64
#  27  total_rev_hi_lim         212999 non-null  int64
# dtypes: float64(13), int64(10), object(5)
# memory usage: 45.5+ MB

# %%
loan['loan_status'].value_counts()
# Out:
# Current        210226
# Charged Off      2773
# Name: loan_status, dtype: int64

# %% [markdown]
# ### Missing Values Treatment:

# %%
(loan.isnull().sum()/len(loan))*100
# Out:
# funded_amnt                0.000000
# term                       0.000000
# int_rate                   0.000000
# installment                0.000000
# grade                      0.000000
# home_ownership             0.000000
# annual_inc                 0.000000
# loan_status                0.000000
# dti                        0.000000
# delinq_2yrs                0.000000
# earliest_cr_line           0.000000
# inq_last_6mths             0.000000
# open_acc                   0.000000
# pub_rec                    0.000000
# revol_bal                  0.000000
# revol_util                 0.038498
# out_prncp                  0.000000
# total_pymnt                0.000000
# total_rec_prncp            0.000000
# total_rec_int              0.000000
# total_rec_late_fee         0.000000
# recoveries                 0.000000
# collection_recovery_fee    0.000000
# last_pymnt_amnt            0.000000
# acc_now_delinq             0.000000
# tot_coll_amt               0.000000
# tot_cur_bal                0.000000
# total_rev_hi_lim           0.000000
# dtype: float64

# %% [markdown]
# **Interpretation:** The plot shows that there are Null values present in `revol_util` column.

# %%
loan['revol_util'].isnull().sum()
# Out:
# 82

# %%
loan.dropna(inplace=True)

# %%
loan['loan_status'].value_counts()
# Out:
# Current        210144
# Charged Off      2773
# Name: loan_status, dtype: int64

# %%
msno.matrix(loan, label_rotation=90)
plt.show()

# %%
loan.shape
# Out:
# (212917, 28)

# %% [markdown]
# **Intepretation:**
# - `revol_util` has 3% of the missing values, so we decided to drop these records rather than imputing them with unknown values.
# - After missing values treatment, our `loan_status` = Charged-Off is not affected and we still have Charged-Off as 1% out of total records.

# %% [markdown]
# ### Convert datatypes to Numeric and Data Cleaning Process:
# - **term**

# %%
loan['term'].unique()
# Out:
# array([' 36 months', ' 60 months'], dtype=object)

# %%
loan['term'] = loan['term'].str.replace(' months', '').astype(int)

# %%
loan['term'].unique()
# Out:
# array([36, 60])

# %%
loan['term'].replace({36:1, 60:2}, inplace=True)

# %%
loan['term'].value_counts()
# Out:
# 1    142970
# 2     69947
# Name: term, dtype: int64

# %%
loan['term'].dtype
# Out:
# dtype('int32')

# %% [markdown]
# - `term` column has two values as 36 months and 60 months, so for better analysis we encoded `36 months = 1` and `60 months = 2`.

# %% [markdown]
# - **earliest_cr_line**

# %%
loan['earliest_cr_line'].unique()
# Out:
# array(['Sep-00', 'Sep-02', 'Feb-06', 'Oct-99', 'Nov-99', 'May-98',
#        'Feb-84', 'Mar-09', 'Jun-04', 'Jul-00', 'Aug-97', 'Jul-85',
#        'Apr-96', 'Oct-03', 'Aug-01', 'Feb-10', 'Aug-96', 'Aug-03',
#        'Jan-97', 'Apr-98', 'Nov-08', 'Jun-83', 'Feb-00', 'Jul-96',
#        'Nov-01', 'Jun-01', 'Feb-05', 'Oct-05', 'Mar-06', 'Nov-89',
#        'Feb-97', 'Jan-92', 'May-02', 'Apr-06', 'Feb-11', 'Feb-98',
#        'Aug-04', 'Sep-99', 'Oct-96', 'Nov-98', 'Sep-05', 'Aug-07',
#        'Jan-05', 'Jun-00', 'Jul-08', 'Mar-02', 'Dec-98', 'Feb-07',
#        'Dec-05', 'Jun-02', 'Jul-06', 'Dec-88', 'Nov-94', 'Nov-96',
#        'Aug-11', 'Oct-95', 'Sep-03', 'Aug-02', 'Dec-84', 'Jun-95',
#        'Oct-00', 'Dec-87', 'Feb-78', 'Feb-04', 'Oct-01', 'Mar-05',
#        'Sep-97', 'Mar-01', 'Jan-81', 'Mar-98', 'Mar-00', 'Mar-03',
#        'Mar-08', 'Mar-85', 'Nov-10', 'Aug-89', 'Dec-11', 'Dec-89',
#        'Dec-02', 'May-99', 'Jan-87', 'Sep-08', 'Oct-04', 'Nov-00',
#        'Sep-95', 'Aug-94', 'Jul-07', 'Jun-86', 'Jan-76', 'Apr-03',
#        'Feb-93', 'Mar-88', 'Apr-90', 'Sep-98', 'Jul-86', 'Feb-94',
#        'Oct-94', 'Sep-01', 'Jun-06', 'Jun-03', 'May-08', 'Aug-00',
#        'Aug-93', 'Feb-01', 'Jan-95', 'May-03', 'Mar-97', 'May-90',
#        'Mar-86', 'Aug-05', 'Sep-09', 'Jun-87', 'Mar-77', 'Jul-99',
#        'May-88', 'Apr-04', 'Jan-06', 'Sep-04', 'May-07', 'Sep-94',
#        'Jun-91', 'Oct-10', 'Apr-89', 'Oct-87', 'Dec-04', 'Sep-07',
#        'Dec-99', 'Mar-91', 'Jun-94', 'Nov-02', 'Aug-92', 'Nov-97',
#        'Aug-10', 'Nov-03', 'May-01', 'Jul-89', 'Aug-99', 'Feb-02',
#        'Nov-06', 'Dec-91', 'Sep-86', 'Apr-12', 'May-96', 'Oct-86',
#        'Jun-93', 'May-11', 'May-09', 'Jul-10', 'Jul-09', 'Jul-04',
#        'Nov-86', 'Jan-98', 'May-05', 'Feb-87', 'Feb-03', 'Dec-10',
#        'Jul-01', 'Jul-87', 'Apr-95', 'May-95', 'Sep-06', 'Apr-88',
#        'Mar-76', 'Nov-04', 'Jul-98', 'Mar-79', 'May-10', 'Jul-03',
#        'Mar-99', 'Nov-07', 'Jan-75', 'Aug-06', 'Jun-85', 'May-00',
#        'Dec-92', 'Jan-99', 'Apr-08', 'Apr-00', 'Dec-79', 'Aug-09',
#        'Dec-97', 'Jan-03', 'Jan-02', 'Sep-93', 'Sep-88', 'Oct-09',
#        'Nov-90', 'Jul-95', 'Dec-03', 'Jun-05', 'Jul-97', 'May-91',
#        'Aug-95', 'Dec-01', 'Jun-96', 'Aug-84', 'Sep-90', 'Dec-00',
#        'Jul-05', 'Mar-94', 'Jun-81', 'Mar-07', 'Oct-93', 'Oct-89',
#        'Apr-81', 'Jan-83', 'Oct-06', 'Feb-99', 'Aug-08', 'Aug-67',
#        'May-70', 'May-94', 'Jan-04', 'Apr-91', 'Dec-94', 'Oct-98',
#        'Jul-93', 'Jul-02', 'Jan-12', 'Jan-01', 'Sep-10', 'Jun-10',
#        'May-04', 'Jun-76', 'Mar-90', 'Nov-87', 'Apr-02', 'Sep-85',
#        'Apr-09', 'Oct-11', 'Oct-07', 'Jun-74', 'Nov-11', 'Apr-11',
#        'Mar-04', 'May-97', 'Feb-89', 'Mar-95', 'Apr-97', 'Oct-97',
#        'Feb-95', 'Jul-91', 'Apr-85', 'Jun-97', 'Dec-96', 'Dec-07',
#        'Aug-91', 'Nov-88', 'Mar-11', 'Sep-84', 'Mar-12', 'Dec-93',
#        'Aug-98', 'Oct-08', 'Jun-88', 'Jun-99', 'Oct-85', 'Jul-94',
#        'May-06', 'Nov-09', 'Jan-85', 'Nov-05', 'Dec-06', 'Jan-00',
#        'Jan-90', 'Nov-73', 'Jun-09', 'Sep-91', 'Feb-86', 'Mar-93',
#        'Apr-84', 'Feb-09', 'May-89', 'Mar-92', 'Nov-91', 'Dec-95',
#        'Jun-11', 'Sep-76', 'Apr-99', 'Aug-88', 'Nov-76', 'Apr-01',
#        'Jun-07', 'Aug-85', 'Oct-92', 'Jan-07', 'Apr-07', 'Jul-84',
#        'Jan-86', 'Oct-70', 'Mar-96', 'Mar-81', 'Jun-79', 'May-87',
#        'Jan-96', 'Dec-90', 'Nov-92', 'Mar-10', 'Apr-05', 'Dec-64',
#        'Apr-92', 'May-79', 'Oct-90', 'Jan-08', 'Jul-83', 'Mar-78',
#        'Feb-79', 'Apr-94', 'Oct-78', 'Nov-95', 'Sep-69', 'Jun-08',
#        'Nov-93', 'Apr-93', 'Oct-02', 'Apr-83', 'Sep-77', 'Aug-70',
#        'Jun-89', 'May-77', 'Dec-74', 'Aug-86', 'Mar-89', 'Jan-94',
#        'Jan-91', 'Apr-10', 'Apr-86', 'Jun-98', 'Dec-08', 'Sep-74',
#        'May-93', 'Jun-90', 'Sep-96', 'Sep-87', 'Jul-90', 'Aug-90',
#        'Feb-82', 'Feb-12', 'Feb-83', 'Jul-88', 'Jan-82', 'Dec-71',
#        'Dec-09', 'Feb-08', 'Apr-78', 'May-92', 'Jan-84', 'Oct-83',
#        'Feb-92', 'Oct-88', 'May-84', 'Nov-84', 'Jan-93', 'Aug-78',
#        'Jun-82', 'Apr-79', 'Jan-10', 'Jun-92', 'Apr-77', 'Sep-11',
#        'May-78', 'May-85', 'Oct-91', 'Jun-71', 'Jul-69', 'Oct-81',
#        'Jan-11', 'Feb-80', 'Dec-85', 'Jul-71', 'Aug-76', 'Mar-63',
#        'Jul-80', 'Jul-65', 'Feb-85', 'May-81', 'Mar-87', 'Mar-75',
#        'Aug-87', 'Feb-96', 'Jan-88', 'Jul-73', 'Nov-85', 'May-75',
#        'Sep-89', 'Apr-87', 'Nov-80', 'Feb-75', 'Feb-88', 'May-83',
#        'Aug-83', 'Aug-77', 'Mar-82', 'Mar-74', 'Jan-62', 'May-72',
#        'Sep-80', 'Oct-62', 'May-74', 'Jan-89', 'Feb-77', 'Jul-11',
#        'Feb-70', 'Oct-82', 'Oct-80', 'Jul-79', 'Sep-92', 'Nov-65',
#        'Sep-79', 'Jul-81', 'Sep-75', 'Jan-74', 'Jan-79', 'Oct-84',
#        'Mar-84', 'Jul-76', 'Feb-73', 'Dec-78', 'May-12', 'Nov-78',
#        'Feb-90', 'Feb-91', 'Nov-66', 'Nov-81', 'Aug-12', 'Sep-12',
#        'Jul-92', 'Jun-70', 'Dec-86', 'May-86', 'Mar-83', 'Dec-82',
#        'Jan-09', 'Oct-79', 'Jan-73', 'Oct-12', 'Jan-68', 'Oct-72',
#        'Jun-12', 'Oct-75', 'Sep-81', 'Jan-80', 'Aug-80', 'Apr-75',
#        'Aug-69', 'Aug-82', 'Mar-80', 'Dec-77', 'Nov-83', 'Jul-82',
#        'May-82', 'Jul-12', 'May-80', 'Feb-81', 'Apr-73', 'May-76',
#        'Nov-79', 'Jan-67', 'Nov-72', 'May-73', 'Apr-80', 'Apr-72',
#        'Sep-63', 'Mar-70', 'Nov-75', 'Feb-68', 'Dec-81', 'Oct-76',
#        'Sep-83', 'Oct-73', 'Aug-79', 'Jun-75', 'Jun-78', 'Dec-65',
#        'Nov-12', 'Nov-77', 'Jan-63', 'Oct-74', 'Sep-78', 'Dec-80',
#        'Jan-72', 'Nov-71', 'Jan-64', 'Aug-81', 'Jul-68', 'Jun-80',
#        'Mar-73', 'Dec-83', 'Dec-73', 'May-71', 'Aug-75', 'Jan-77',
#        'Jun-84', 'Jul-74', 'Mar-71', 'Nov-69', 'Feb-69', 'Oct-68',
#        'Jan-69', 'Jul-78', 'Oct-77', 'Dec-75', 'Dec-66', 'Feb-72',
#        'Feb-71', 'Jul-77', 'Nov-82', 'Apr-82', 'Apr-70', 'Sep-82',
#        'Dec-70', 'Oct-66', 'Jun-69', 'Jan-60', 'Nov-68', 'Feb-65',
#        'Feb-76', 'Apr-74', 'Dec-72', 'Sep-70', 'May-67', 'Jun-73',
#        'Apr-66', 'Jun-68', 'Jan-78', 'Jan-61', 'Aug-62', 'Dec-76',
#        'Aug-73', 'Jun-72', 'Dec-62', 'Jun-77', 'May-61', 'Jul-75',
#        'Dec-58', 'Mar-72', 'Aug-71', 'Mar-67', 'Jan-59', 'Jul-63',
#        'Aug-74', 'Apr-67', 'Mar-69', 'Sep-73', 'Oct-58', 'Apr-76',
#        'Sep-72', 'Nov-74', 'Feb-74', 'Feb-59', 'May-69', 'Sep-66',
#        'Aug-68', 'Oct-59', 'Jan-50', 'Oct-64', 'Jun-65', 'Feb-61',
#        'Jun-67', 'Nov-67', 'Nov-70', 'Sep-61', 'Dec-63', 'Apr-69',
#        'Oct-71', 'Mar-62', 'Oct-69', 'Jul-70', 'Dec-68', 'Jun-62',
#        'May-65', 'Apr-65', 'Jun-66', 'Jan-65', 'Jun-55', 'Jul-72',
#        'Jan-70', 'May-64', 'Feb-67', 'Jan-71', 'Sep-67', 'Aug-66',
#        'Feb-64', 'Dec-67', 'Apr-71', 'May-68', 'Jul-67', 'Jul-66',
#        'Sep-65', 'Dec-69', 'Jan-66', 'Sep-68', 'Sep-71', 'Jun-63',
#        'Oct-65', 'Oct-63', 'Aug-64', 'Aug-72', 'Apr-63', 'Feb-66',
#        'Apr-68', 'Sep-53', 'Jan-56', 'May-66', 'Mar-68', 'Apr-55',
#        'Aug-59', 'Sep-64', 'May-63', 'Jun-58', 'Nov-56', 'Jul-59',
#        'Jan-55', 'Mar-66', 'Mar-58', 'Jan-58', 'Dec-59', 'Apr-62',
#        'Apr-60', 'Nov-57', 'Nov-62', 'Jun-64', 'May-60', 'Oct-67',
#        'Aug-60', 'Sep-62', 'Jul-62', 'May-55', 'Mar-60', 'Nov-64',
#        'Aug-51', 'Aug-65', 'Sep-59', 'Nov-59', 'Apr-64', 'Mar-64',
#        'Jan-53', 'Mar-65', 'Nov-58', 'Sep-56', 'Dec-61', 'May-57',
#        'Mar-61', 'Jan-57', 'May-62', 'Aug-61', 'Dec-56', 'Jun-57',
#        'Jul-64', 'Dec-60'], dtype=object)

# %%
loan['earliest_cr_line'] = loan['earliest_cr_line'].str.split('-', expand=True)[1]

# %%
loan['earliest_cr_line'].unique()
# Out:
# array(['00', '02', '06', '99', '98', '84', '09', '04', '97', '85', '96',
#        '03', '01', '10', '08', '83', '05', '89', '92', '11', '07', '88',
#        '94', '95', '87', '78', '81', '86', '76', '93', '90', '77', '91',
#        '12', '79', '75', '67', '70', '74', '73', '64', '69', '82', '71',
#        '80', '63', '65', '62', '72', '66', '68', '60', '61', '58', '59',
#        '50', '55', '53', '56', '57', '51'], dtype=object)

# %% [markdown]
# - Since earliest_cr_line is `object` datatype, we will first convert it to `string`.

# %%
loan['earliest_cr_line'] = loan['earliest_cr_line'].convert_dtypes(convert_string=True)

# %%
def earliest_cr_line_year(x):
    if (x[0] == '0') or (x[0] == '1'):
        return '20'+x
    if (x[0] == '5') or (x[0] == '6') or (x[0] == '7') or (x[0] == '8') or (x[0] == '9'):
        return '19'+x

# %%
loan['cr_year'] =loan['earliest_cr_line'].map(earliest_cr_line_year)

# %%
loan['cr_year'].unique()
# Out:
# array(['2000', '2002', '2006', '1999', '1998', '1984', '2009', '2004',
#        '1997', '1985', '1996', '2003', '2001', '2010', '2008', '1983',
#        '2005', '1989', '1992', '2011', '2007', '1988', '1994', '1995',
#        '1987', '1978', '1981', '1986', '1976', '1993', '1990', '1977',
#        '1991', '2012', '1979', '1975', '1967', '1970', '1974', '1973',
#        '1964', '1969', '1982', '1971', '1980', '1963', '1965', '1962',
#        '1972', '1966', '1968', '1960', '1961', '1958', '1959', '1950',
#        '1955', '1953', '1956', '1957', '1951'], dtype=object)

# %%
loan['earliest_cr_line'] = loan['cr_year'].astype(int)

# %%
loan['earliest_cr_line'].dtypes
# Out:
# dtype('int32')

# %%
loan.drop(columns=['cr_year'], inplace=True)

# %% [markdown]
# **Interpretation:**
#
# - But according to the data definition, `term` is interpreted as `object`, so we will extract month from this variable and convert data type to `int`.
#
# - Similarly, `earliest_cr_line` is interpreted as `object`, so we will extract year from this variable and convert data type to `int`.

# %%
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 212917 entries, 0 to 212998
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   funded_amnt              212917 non-null  int64
#  1   term                     212917 non-null  int32
#  2   int_rate                 212917 non-null  float64
#  3   installment              212917 non-null  float64
#  4   grade                    212917 non-null  object
#  5   home_ownership           212917 non-null  object
#  6   annual_inc               212917 non-null  float64
#  7   loan_status              212917 non-null  object
#  8   dti                      212917 non-null  float64
#  9   delinq_2yrs              212917 non-null  int64
#  10  earliest_cr_line         212917 non-null  int32
#  11  inq_last_6mths           212917 non-null  int64
#  12  open_acc                 212917 non-null  int64
#  13  pub_rec                  212917 non-null  int64
#  14  revol_bal                212917 non-null  int64
#  15  revol_util               212917 non-null  float64
#  16  out_prncp                212917 non-null  float64
#  17  total_pymnt              212917 non-null  float64
#  18  total_rec_prncp          212917 non-null  float64
#  19  total_rec_int            212917 non-null  float64
#  20  total_rec_late_fee       212917 non-null  float64
#  21  recoveries               212917 non-null  float64
#  22  collection_recovery_fee  212917 non-null  float64
#  23  last_pymnt_amnt          212917 non-null  float64
#  24  acc_now_delinq           212917 non-null  int64
#  25  tot_coll_amt             212917 non-null  int64
#  26  tot_cur_bal              212917 non-null  int64
#  27  total_rev_hi_lim         212917 non-null  int64
# dtypes: float64(13), int32(2), int64(10), object(3)
# memory usage: 45.5+ MB

# %% [markdown]
# **Interpretation:**
# - The data has `212917` observations and `28` attributes.
# - There are 13 float, 12 int and 3 object values.

# %%
loan.head()
# Out:
#    funded_amnt  term  int_rate  installment grade home_ownership  annual_inc  \
# 0        20000     1     12.29       667.06     C            OWN     65000.0
# 1        11000     1     12.69       369.00     C       MORTGAGE     40000.0
# 2         7000     1      9.99       225.84     B       MORTGAGE     32000.0
# 3        10000     1     10.99       327.34     B       MORTGAGE     48000.0
# 4         9550     1     19.99       354.87     E           RENT     32376.0
#
#    loan_status    dti  delinq_2yrs  earliest_cr_line  inq_last_6mths  \
# 0  Charged Off  20.72            0              2000               1
# 1  Charged Off  24.57            0              2002               0
# 2  Charged Off  32.41            0              2006               1
# 3  Charged Off  30.98            0              1999               2
# 4  Charged Off  32.54            0              1999               3
#
#    open_acc  pub_rec  revol_bal  revol_util  out_prncp  total_pymnt  \
# 0        25        0      31578        77.0        0.0         0.00
# 1        13        1       5084        38.8        0.0     10043.49
# 2        18        0      12070        74.0        0.0       221.96
# 3        18        0      22950        66.0        0.0       315.13
# 4         9        0       4172        29.6        0.0       333.66
#
#    total_rec_prncp  total_rec_int  total_rec_late_fee  recoveries  \
# 0             0.00           0.00                 0.0         0.0
# 1          9942.67         100.81                 0.0         0.0
# 2           167.56          54.40                 0.0         0.0
# 3           235.76          79.37                 0.0         0.0
# 4           195.78         137.88                 0.0         0.0
#
#    collection_recovery_fee  last_pymnt_amnt  acc_now_delinq  tot_coll_amt  \
# 0                      0.0             0.00               0             0
# 1                      0.0         10059.00               0           332
# 2                      0.0           225.84               0             0
# 3                      0.0           327.34               0             0
# 4                      0.0           354.87               0             0
#
#    tot_cur_bal  total_rev_hi_lim
# 0        52303             41000
# 1       175731             13100
# 2       202012             16300
# 3       108235             34750
# 4        45492             14100

# %% [markdown]
# ### 5-Point Summary for Numeric and Categorical Data:

# %%
# 5-point summary of numeric variables

loan.describe().T
# Out:
#                             count           mean            std      min  \
# funded_amnt              212917.0   15258.708910    8611.239249  1000.00
# term                     212917.0       1.328518       0.469675     1.00
# int_rate                 212917.0      12.400560       4.248986     5.32
# installment              212917.0     440.851359     245.836263    30.12
# annual_inc               212917.0   77792.383591   81877.734734     0.00
# dti                      212917.0      19.361862      31.931499     0.00
# delinq_2yrs              212917.0       0.347328       0.920960     0.00
# earliest_cr_line         212917.0    1998.344228       7.643860  1950.00
# inq_last_6mths           212917.0       0.564901       0.861789     0.00
# open_acc                 212917.0      11.977409       5.662866     1.00
# pub_rec                  212917.0       0.234425       0.662528     0.00
# revol_bal                212917.0   17989.669853   24571.354172     0.00
# revol_util               212917.0      53.343256      23.903506     0.00
# out_prncp                212917.0   14182.234129    8347.562290     0.00
# total_pymnt              212917.0    1364.129451    1301.894535     0.00
# total_rec_prncp          212917.0     891.471017     996.996612     0.00
# total_rec_int            212917.0     468.135109     479.856499     0.00
# total_rec_late_fee       212917.0       0.047184       1.230846     0.00
# recoveries               212917.0       4.476142     156.672691     0.00
# collection_recovery_fee  212917.0       0.716020      22.898209     0.00
# last_pymnt_amnt          212917.0     436.176260     450.724675     0.00
# acc_now_delinq           212917.0       0.005721       0.081061     0.00
# tot_coll_amt             212917.0     262.039950    2215.608581     0.00
# tot_cur_bal              212917.0  141623.388997  156821.284773     0.00
# total_rev_hi_lim         212917.0   34451.190661   35300.943242     0.00
#
#                               25%       50%        75%           max
# funded_amnt               8500.00  14000.00   20000.00  3.500000e+04
# term                         1.00      1.00       2.00  2.000000e+00
# int_rate                     9.17     12.29      14.65  2.899000e+01
# installment                262.23    382.87     578.79  1.445460e+03
# annual_inc               47000.00  65000.00   92500.00  9.000000e+06
# dti                         12.66     18.72      25.52  9.999000e+03
# delinq_2yrs                  0.00      0.00       0.00  3.000000e+01
# earliest_cr_line          1994.00   2000.00    2004.00  2.012000e+03
# inq_last_6mths               0.00      0.00       1.00  5.000000e+00
# open_acc                     8.00     11.00      15.00  8.200000e+01
# pub_rec                      0.00      0.00       0.00  8.600000e+01
# revol_bal                 6549.00  12063.00   21591.00  1.630818e+06
# revol_util                  35.50     53.50      71.70  1.930000e+02
# out_prncp                 7653.73  12824.81   19494.53  4.937286e+04
# total_pymnt                507.48   1029.37    1859.63  3.577370e+04
# total_rec_prncp            328.29    656.92    1165.99  3.496328e+04
# total_rec_int              142.92    310.89     631.08  4.722360e+03
# total_rec_late_fee           0.00      0.00       0.00  1.247600e+02
# recoveries                   0.00      0.00       0.00  2.630847e+04
# collection_recovery_fee      0.00      0.00       0.00  2.037494e+03
# last_pymnt_amnt            250.05    375.43     572.61  3.533049e+04
# acc_now_delinq               0.00      0.00       0.00  5.000000e+00
# tot_coll_amt                 0.00      0.00       0.00  3.807570e+05
# tot_cur_bal              31432.00  81376.00  209682.00  4.127799e+06
# total_rev_hi_lim         14600.00  25100.00   42600.00  1.641300e+06

# %% [markdown]
# **Interpretation:**
# - We can find the below details for all the numeric columns:
#     - minimum value
#     - maximum value
#     - median value
#     - Q1 and Q3 values
#     - average value

# %%
# 5-point summary of categorical variables

loan.describe(include=object)
# Out:
#          grade home_ownership loan_status
# count   212917         212917      212917
# unique       7              4           2
# top          B       MORTGAGE     Current
# freq     62645         105961      210144

# %% [markdown]
# **Interpretation:**
# - We can find the below details for all the categorical columns:
#     - total count of each categorical column
#     - unique values in each categorical column
#     - top category and its frequency

# %% [markdown]
# ### Checking for Significant Features:
# 1) Analyis of `delinq_2yrs` : **Number of delinquencies(late installment payment) by the borrower in the past 2 years** column-

# %%
loan['delinq_2yrs'].value_counts()
# Out:
# 0     168748
# 1      28989
# 2       8633
# 3       3247
# 4       1504
# 5        749
# 6        418
# 7        215
# 8        138
# 9         77
# 10        69
# 11        46
# 12        25
# 13        23
# 14        10
# 15        10
# 16         8
# 18         2
# 17         2
# 26         2
# 30         1
# 20         1
# Name: delinq_2yrs, dtype: int64

# %%
def delinq_2yrs_levels(x):
    if x==1 or x==2:
        return 'Early Stage'
    elif x==3 or x==4:
        return 'Moderate'
    elif x>=5:
        return 'Severe'
    else:
        return 'Clean'

# %%
loan['delinq_2yrs'] = loan['delinq_2yrs'].apply(delinq_2yrs_levels)

# %%
del_2yrs = pd.DataFrame({'Count':loan['delinq_2yrs'].value_counts(),
           'Proportion(%)':round(loan['delinq_2yrs'].value_counts(normalize=True)*100,2)})
del_2yrs
# Out:
#               Count  Proportion(%)
# Clean        168748          79.26
# Early Stage   37622          17.67
# Moderate       4751           2.23
# Severe         1796           0.84

# %%
fig, ax = plt.subplots(figsize=(10,5))
del_2yrs.plot(kind='bar', y='Count', ax=ax)
plt.xlabel('Delinquency 2 yrs', fontsize = 13)
plt.ylabel('Frequency (Count)', fontsize = 13)
plt.yticks()
plt.title('Distribution of Delinquency for 2 yrs', fontsize=14, fontweight=550)

plt.xticks(rotation = 'horizontal')
plt.legend('')

for x,y in enumerate(del_2yrs['Count']):
    delinq_value = del_2yrs.index[x]
    plt.text(x, y+1500, del_2yrs['Proportion(%)'].loc[delinq_value], horizontalalignment='center', fontweight=700)

plt.show()

# %% [markdown]
# **Inference:**
# - The distribution of delinquencies in past 2 years for Non-Defaulters (Current) is ~79% and distribution for Defaulters (Charged-Off) is remaining ~21%.  We have split Defaulters in three sub categories for futher analysis.
# - Although the distribution is imbalanced it still looks good for the purpose of this analysis as the frequency (counts) values are not small.
#
# **Actions:**
# - Perform dummy encoding during training.

# %% [markdown]
# 2) Analysis of `pub_rec` : **Number of derogatory public records** column-

# %%
loan['pub_rec'].value_counts()
# Out:
# 0     175241
# 1      30458
# 2       4701
# 3       1472
# 4        517
# 5        235
# 6        127
# 7         51
# 8         50
# 10        15
# 9         14
# 11         9
# 12         7
# 13         5
# 16         3
# 15         2
# 21         2
# 23         1
# 26         1
# 17         1
# 28         1
# 86         1
# 18         1
# 14         1
# 19         1
# Name: pub_rec, dtype: int64

# %%
def pub_rec_levels(x):
    if x == 0:
        return 'No'
    else:
        return 'Yes'

# %%
loan['pub_rec'] = loan['pub_rec'].map(pub_rec_levels)

# %%
pub_rec = pd.DataFrame({'Count':loan['pub_rec'].value_counts(),
                       'Proportion(%)':round(loan['pub_rec'].value_counts(normalize=True)*100, 2)})
pub_rec
# Out:
#       Count  Proportion(%)
# No   175241           82.3
# Yes   37676           17.7

# %%
loan['pub_rec'].value_counts()
# Out:
# No     175241
# Yes     37676
# Name: pub_rec, dtype: int64

# %%
pub_recs = pd.DataFrame({'Count':loan['pub_rec'].value_counts(),
           'Proportion(%)':round(loan['pub_rec'].value_counts(normalize=True)*100,2)})
pub_recs
# Out:
#       Count  Proportion(%)
# No   175241           82.3
# Yes   37676           17.7

# %%
fig, ax = plt.subplots(figsize=(10,5))
pub_recs.plot(kind='bar', y='Count', ax=ax)
plt.xlabel('Have Public Records', fontsize = 13)
plt.ylabel('Frequency (Count)', fontsize = 13)
plt.yticks()
plt.title('Distribution of Public Records', fontsize=14, fontweight=550)
plt.xticks(rotation = 'horizontal')
plt.legend('')

for x,y in enumerate(pub_recs['Count']):
    pubrec_value = pub_recs.index[x]
    plt.text(x, y+1500, pub_recs['Proportion(%)'].loc[pubrec_value], horizontalalignment='center', fontweight=700)

plt.show()

# %% [markdown]
# **Inference:**
# - The distribution of number of derogatory public records for Non-Defaulters (Current) is ~82% and distribution for Defaulters (Charged-Off) is remaining ~18%.
# - Although the distribution is imbalanced it still looks good for the purpose of this analysis to see its influence on target variable.
#
# **Actions:**
# - Perform dummy encoding during training.

# %% [markdown]
# 3) Analysis of `recoveries` : **Total recovery procedures initiated against the borrower** column-

# %%
loan['recoveries'].value_counts()
# Out:
# 0.00        212611
# 1053.50          2
# 1000.00          2
# 2837.22          1
# 1066.57          1
# 5008.00          1
# 2828.46          1
# 519.70           1
# 2996.97          1
# 2009.93          1
# 1441.94          1
# 3169.93          1
# 1079.85          1
# 527.54           1
# 5890.29          1
# 3189.20          1
# 5902.57          1
# 3418.67          1
# 654.20           1
# 2696.98          1
# 1595.16          1
# 1322.93          1
# 6057.97          1
# 2098.90          1
# 2585.51          1
# 4433.99          1
# 1190.81          1
# 5360.15          1
# 1572.19          1
# 2009.33          1
# 1700.70          1
# 4683.56          1
# 3896.31          1
# 997.60           1
# 2529.67          1
# 3555.63          1
# 3251.56          1
# 2640.13          1
# 2799.45          1
# 1524.11          1
# 4180.91          1
# 5543.65          1
# 4280.05          1
# 4559.71          1
# 1221.41          1
# 2359.18          1
# 596.56           1
# 1103.41          1
# 5508.34          1
# 6162.58          1
# 1819.35          1
# 5511.39          1
# 2473.49          1
# 2632.89          1
# 2078.79          1
# 1629.31          1
# 1356.24          1
# 3564.00          1
# 3838.07          1
# 5439.39          1
# 3790.90          1
# 855.89           1
# 989.82           1
# 8500.00          1
# 3764.12          1
# 2077.70          1
# 2721.64          1
# 358.50           1
# 1074.27          1
# 2448.46          1
# 5204.12          1
# 1049.50          1
# 1487.61          1
# 2670.64          1
# 4309.18          1
# 4377.30          1
# 971.58           1
# 4663.45          1
# 1056.82          1
# 1748.21          1
# 822.74           1
# 3508.13          1
# 2753.64          1
# 2803.97          1
# 6132.11          1
# 2828.04          1
# 2134.36          1
# 1731.26          1
# 6182.61          1
# 3923.78          1
# 4342.02          1
# 5978.94          1
# 4329.46          1
# 1076.81          1
# 4934.60          1
# 3619.79          1
# 1998.85          1
# 4683.02          1
# 467.20           1
# 5834.18          1
# 1413.48          1
# 21941.26         1
# 3472.03          1
# 2296.66          1
# 6459.61          1
# 2673.60          1
# 2820.97          1
# 2527.30          1
# 6569.23          1
# 1124.87          1
# 4836.81          1
# 3814.24          1
# 4550.73          1
# 4050.71          1
# 4053.15          1
# 20.00            1
# 2917.31          1
# 1889.82          1
# 1026.05          1
# 621.99           1
# 1240.00          1
# 1017.18          1
# 3218.31          1
# 1699.69          1
# 4403.86          1
# 1655.73          1
# 1800.84          1
# 715.69           1
# 1302.84          1
# 3598.98          1
# 1167.73          1
# 5950.24          1
# 3860.27          1
# 5232.91          1
# 2273.28          1
# 2879.18          1
# 2746.67          1
# 406.34           1
# 3437.77          1
# 4128.70          1
# 1192.58          1
# 1080.00          1
# 6321.77          1
# 2864.90          1
# 4218.83          1
# 4877.96          1
# 2345.40          1
# 2001.44          1
# 1807.09          1
# 2506.87          1
# 8264.96          1
# 2662.61          1
# 1349.27          1
# 6283.74          1
# 3803.56          1
# 11319.41         1
# 3276.44          1
# 1860.50          1
# 1630.60          1
# 5795.08          1
# 2176.12          1
# 6507.09          1
# 419.17           1
# 3955.29          1
# 4988.30          1
# 2923.06          1
# 5225.55          1
# 2864.50          1
# 6529.35          1
# 1731.21          1
# 629.55           1
# 4742.91          1
# 2228.69          1
# 892.48           1
# 1065.56          1
# 5833.02          1
# 1692.20          1
# 4894.68          1
# 1304.53          1
# 200.00           1
# 2013.05          1
# 1697.73          1
# 3077.24          1
# 652.00           1
# 2243.86          1
# 766.62           1
# 74.16            1
# 3827.89          1
# 3208.50          1
# 5776.89          1
# 1460.77          1
# 4236.70          1
# 4434.54          1
# 226.39           1
# 2850.94          1
# 183.55           1
# 3661.32          1
# 1267.92          1
# 1108.42          1
# 2134.77          1
# 1096.50          1
# 1931.82          1
# 29.00            1
# 4673.92          1
# 7516.32          1
# 1408.10          1
# 12427.85         1
# 3472.19          1
# 5146.50          1
# 222.50           1
# 2885.45          1
# 1645.61          1
# 14746.89         1
# 1029.26          1
# 4402.30          1
# 1065.30          1
# 1602.76          1
# 5891.31          1
# 1832.63          1
# 1817.30          1
# 5406.77          1
# 5616.69          1
# 6359.65          1
# 4571.56          1
# 1345.86          1
# 2284.36          1
# 4185.14          1
# 2235.04          1
# 2367.75          1
# 2856.84          1
# 26308.47         1
# 4089.81          1
# 628.63           1
# 2287.99          1
# 5201.51          1
# 926.85           1
# 2816.08          1
# 2103.98          1
# 1939.32          1
# 1669.52          1
# 2455.69          1
# 3559.35          1
# 6094.39          1
# 102.26           1
# 882.92           1
# 4423.25          1
# 2245.76          1
# 426.27           1
# 208.55           1
# 3665.20          1
# 4527.17          1
# 3498.35          1
# 2081.86          1
# 517.32           1
# 6354.40          1
# 5479.81          1
# 769.75           1
# 1844.09          1
# 12679.50         1
# 4330.99          1
# 6211.27          1
# 2617.25          1
# 1534.41          1
# 328.72           1
# 2262.61          1
# 3519.96          1
# 3073.39          1
# 1157.36          1
# 1045.94          1
# 2406.29          1
# 1497.91          1
# 1708.01          1
# 2075.91          1
# 542.84           1
# 1582.95          1
# 157.46           1
# 2509.88          1
# 354.72           1
# 1654.80          1
# 1304.54          1
# 1441.67          1
# 3322.36          1
# 2501.83          1
# 2550.78          1
# 4339.99          1
# 3569.63          1
# 715.56           1
# 4958.04          1
# 2788.78          1
# 4199.27          1
# 3881.14          1
# 1350.00          1
# 4293.08          1
# 6442.22          1
# 2043.50          1
# 1223.20          1
# 177.78           1
# 4850.28          1
# 2659.95          1
# 3426.51          1
# 2853.39          1
# 3942.12          1
# 3967.89          1
# 3238.12          1
# 6371.02          1
# Name: recoveries, dtype: int64

# %%
def recoveries_levels(x):
    if x == 0:
        return 'No'
    else:
        return 'Yes'

# %%
loan['recoveries'] = loan['recoveries'].map(recoveries_levels)

# %%
rec_prop = pd.DataFrame({'Count':loan['recoveries'].value_counts(),
                       'Proportion(%)':round(loan['recoveries'].value_counts(normalize=True)*100, 2)})
rec_prop
# Out:
#       Count  Proportion(%)
# No   212611          99.86
# Yes     306           0.14

# %%
fig, ax = plt.subplots(figsize=(10,5))
rec_prop.plot(kind='bar', y='Count', ax=ax)
plt.xlabel('Recoveries', fontsize = 13)
plt.ylabel('Frequency (Count)', fontsize = 13)
plt.yticks()
plt.title('Distribution of Recoveries against Borrower', fontsize=14, fontweight=550)
plt.xticks(rotation = 'horizontal')
plt.legend('')

for x,y in enumerate(rec_prop['Count']):
    rec_value = rec_prop.index[x]
    plt.text(x, y+1500, rec_prop['Proportion(%)'].loc[rec_value], horizontalalignment='center', fontweight=700)

plt.show()

# %% [markdown]
# **Inference:**
#
# - The distribution is extremely imbalanced and the frequency (counts) value of 'Non-Recoveries' is almost 0 and thus will not add value (information) to our analysis.
#
# **Actions:**
#
# - Drop the feature `recoveries`.

# %% [markdown]
# 4) Analysis of `collection_recovery_fee` : **The fees collected during the recovery procedures** column-

# %%
loan['collection_recovery_fee'].value_counts()
# Out:
# 0.0000       212616
# 189.6300          2
# 180.0000          2
# 361.7874          1
# 485.4564          1
# 191.9826          1
# 901.4400          1
# 28.2846           1
# 93.5460           1
# 539.4546          1
# 259.5492          1
# 238.1274          1
# 510.6996          1
# 570.5874          1
# 94.9572           1
# 1060.2522         1
# 574.0560          1
# 1062.4626         1
# 615.3606          1
# 194.3730          1
# 475.2234          1
# 287.1288          1
# 503.9010          1
# 174.8844          1
# 377.8020          1
# 465.3918          1
# 44.3399           1
# 214.3458          1
# 964.8270          1
# 282.9942          1
# 361.6794          1
# 306.1260          1
# 843.0408          1
# 38.9631           1
# 179.5680          1
# 455.3406          1
# 640.0134          1
# 585.2808          1
# 117.7560          1
# 1090.4346         1
# 839.4210          1
# 752.5638          1
# 997.8570          1
# 641.5200          1
# 770.4090          1
# 820.7478          1
# 219.8538          1
# 424.6524          1
# 107.3808          1
# 198.6138          1
# 991.5012          1
# 1109.2644         1
# 327.4830          1
# 992.0502          1
# 445.2282          1
# 473.9202          1
# 374.1822          1
# 690.8526          1
# 682.3620          1
# 787.9140          1
# 489.8952          1
# 274.3398          1
# 154.0602          1
# 178.1676          1
# 1530.0000         1
# 677.5416          1
# 373.9860          1
# 64.5300           1
# 775.6524          1
# 193.3686          1
# 440.7228          1
# 936.7416          1
# 188.9100          1
# 267.7698          1
# 480.7152          1
# 979.0902          1
# 525.1158          1
# 244.1232          1
# 314.6778          1
# 148.0932          1
# 631.4634          1
# 495.6552          1
# 504.7146          1
# 1103.7798         1
# 509.0472          1
# 384.1848          1
# 311.6268          1
# 1112.8698         1
# 706.2804          1
# 781.5636          1
# 1076.2092         1
# 779.3028          1
# 193.8258          1
# 888.2280          1
# 651.5622          1
# 359.7930          1
# 694.8486          1
# 84.0960           1
# 1050.1524         1
# 254.4264          1
# 571.1058          1
# 624.9654          1
# 413.3988          1
# 1162.7298         1
# 481.2480          1
# 507.7746          1
# 454.9140          1
# 1182.4614         1
# 202.4766          1
# 870.6258          1
# 686.5632          1
# 819.1314          1
# 729.1278          1
# 729.5670          1
# 842.9436          1
# 3.6000            1
# 518.2524          1
# 941.9238          1
# 184.6890          1
# 111.9582          1
# 223.2000          1
# 183.0924          1
# 579.2958          1
# 305.9442          1
# 792.6948          1
# 298.0314          1
# 324.1512          1
# 128.8242          1
# 234.5112          1
# 35.9898           1
# 210.1914          1
# 1071.0432         1
# 340.1676          1
# 409.1904          1
# 494.4006          1
# 515.6820          1
# 73.1412           1
# 618.7986          1
# 743.1660          1
# 214.6644          1
# 194.4000          1
# 1137.9186         1
# 759.3894          1
# 479.2698          1
# 878.0328          1
# 422.1720          1
# 360.2592          1
# 325.2762          1
# 25.0687           1
# 1487.6928         1
# 293.2758          1
# 242.8686          1
# 926.3700          1
# 191.8008          1
# 2037.4938         1
# 853.7238          1
# 589.7592          1
# 334.8900          1
# 293.5080          1
# 1043.1144         1
# 391.7016          1
# 1171.2762         1
# 75.4506           1
# 711.9522          1
# 897.8940          1
# 526.1508          1
# 940.5990          1
# 515.6100          1
# 1175.2830         1
# 401.1642          1
# 1039.8402         1
# 190.2276          1
# 577.5300          1
# 798.2172          1
# 426.1950          1
# 1049.9436         1
# 304.5960          1
# 881.0424          1
# 234.8154          1
# 36.0000           1
# 362.3490          1
# 305.5914          1
# 553.9032          1
# 117.3600          1
# 403.8948          1
# 137.9916          1
# 13.3488           1
# 689.0202          1
# 311.6178          1
# 113.3190          1
# 262.9386          1
# 160.6464          1
# 40.7502           1
# 40.0500           1
# 513.1692          1
# 33.0390           1
# 659.0376          1
# 228.2256          1
# 199.5156          1
# 384.2586          1
# 197.3700          1
# 347.7276          1
# 5.2200            1
# 841.3056          1
# 1352.9376         1
# 253.4580          1
# 624.9942          1
# 519.3810          1
# 402.3072          1
# 753.3252          1
# 1060.4358         1
# 762.6060          1
# 296.2098          1
# 185.2668          1
# 792.4140          1
# 191.7540          1
# 288.4968          1
# 329.8734          1
# 411.1848          1
# 327.1140          1
# 973.2186          1
# 1011.0042         1
# 1144.7370         1
# 822.8808          1
# 242.2548          1
# 514.2312          1
# 188.2692          1
# 781.1982          1
# 404.2368          1
# 736.1658          1
# 76.7286           1
# 113.1534          1
# 411.8382          1
# 936.2718          1
# 166.8330          1
# 506.8944          1
# 378.7164          1
# 349.0776          1
# 300.5136          1
# 442.0242          1
# 640.6830          1
# 1096.9902         1
# 18.4068           1
# 158.9256          1
# 37.5390           1
# 814.8906          1
# 633.5928          1
# 986.3658          1
# 684.6408          1
# 1131.0732         1
# 629.7030          1
# 374.7348          1
# 93.1176           1
# 1143.7920         1
# 138.5550          1
# 407.2698          1
# 331.9362          1
# 779.5782          1
# 1118.0286         1
# 471.1050          1
# 276.1938          1
# 59.1696           1
# 796.1850          1
# 553.2102          1
# 459.1404          1
# 659.7360          1
# 433.1322          1
# 642.5334          1
# 269.6238          1
# 307.4418          1
# 373.6638          1
# 97.7112           1
# 284.9310          1
# 28.3428           1
# 451.7784          1
# 63.8496           1
# 297.8640          1
# 234.8172          1
# 259.5006          1
# 598.0248          1
# 450.3294          1
# 128.8008          1
# 501.9804          1
# 582.8616          1
# 1159.5996         1
# 208.3248          1
# 892.4472          1
# 755.8686          1
# 698.6052          1
# 243.0000          1
# 772.7544          1
# 367.8300          1
# 714.2202          1
# 220.1760          1
# 32.0004           1
# 478.7910          1
# 616.7718          1
# 513.6102          1
# 709.5816          1
# 1146.7836         1
# Name: collection_recovery_fee, dtype: int64

# %%
def crf_levels(x):
    if x == 0:
        return 'No'
    else:
        return 'Yes'

# %%
loan['collection_recovery_fee'] = loan['collection_recovery_fee'].map(crf_levels)

# %%
crf_prop = pd.DataFrame({'Count':loan['collection_recovery_fee'].value_counts(),
                       'Proportion(%)':round(loan['collection_recovery_fee'].value_counts(normalize=True)*100, 2)})
crf_prop
# Out:
#       Count  Proportion(%)
# No   212616          99.86
# Yes     301           0.14

# %%
fig, ax = plt.subplots(figsize=(10,5))
crf_prop.plot(kind='bar', y='Count', ax=ax)
plt.xlabel('Collection Recovery Fees', fontsize = 13)
plt.ylabel('Frequency (Count)', fontsize = 13)
plt.yticks()
plt.title('Distribution of Collection Recovery Fees', fontsize=14, fontweight=550)
plt.xticks(rotation = 'horizontal')
plt.legend('')

for x,y in enumerate(crf_prop['Count']):
    crf_value = crf_prop.index[x]
    plt.text(x, y+1500, crf_prop['Proportion(%)'].loc[crf_value], horizontalalignment='center', fontweight=700)

plt.show()

# %% [markdown]
# **Inference:**
#
# - The distribution is extremely imbalanced and the frequency (counts) value of 'Non-Recoveries' is almost 0 and thus will not add value (information) to our analysis.
#
# **Actions:**
#
# - Drop the feature `collection_recovery_fee`.

# %% [markdown]
# 5) Analysis of `acc_now_delinq` : **Number of accounts on which the borrower is now delinquent** column-

# %%
loan['acc_now_delinq'].value_counts()
# Out:
# 0    211776
# 1      1076
# 2        57
# 3         5
# 4         2
# 5         1
# Name: acc_now_delinq, dtype: int64

# %%
def and_levels(x):
    if x == 0:
        return 'No'
    else:
        return 'Yes'

# %%
loan['acc_now_delinq'] = loan['acc_now_delinq'].map(and_levels)

# %%
and_prop = pd.DataFrame({'Count':loan['acc_now_delinq'].value_counts(),
                       'Proportion(%)':round(loan['acc_now_delinq'].value_counts(normalize=True)*100, 2)})
and_prop
# Out:
#       Count  Proportion(%)
# No   211776          99.46
# Yes    1141           0.54

# %%
fig, ax = plt.subplots(figsize=(10,5))
and_prop.plot(kind='bar', y='Count', ax=ax)
plt.xlabel('Account Now Delinquent', fontsize = 13)
plt.ylabel('Count', fontsize = 13)
plt.yticks()
plt.title('Distribution of Account Now Delinquent', fontsize=14, fontweight=550)
plt.xticks(rotation = 'horizontal')
plt.legend('')

for x,y in enumerate(and_prop['Count']):
    and_value = and_prop.index[x]
    plt.text(x, y+1500, and_prop['Proportion(%)'].loc[and_value], horizontalalignment='center', fontweight=700)

plt.show()

# %% [markdown]
# **Inference:**
#
# - The distribution is extremely imbalanced and the frequency (counts) value of 'Non-Recoveries' is 0.5% only and thus will not add value (information) to our analysis.
#
# **Actions:**
#
# - Drop the feature `acc_now_delinq`.

# %% [markdown]
# 6) Analysis of `inq_last_6mths` : **Inquiries for loans made by the borrower over the past 6 months** column-

# %%
loan['inq_last_6mths'].value_counts()
# Out:
# 0    130654
# 1     55630
# 2     18170
# 3      6130
# 4      1748
# 5       585
# Name: inq_last_6mths, dtype: int64

# %%
def inq_levels(x):
    if x==1 or x==2:
        return 'Low '
    elif x>=3:
        return 'High'
    else:
        return 'No'

# %%
loan['inq_last_6mths'] = loan['inq_last_6mths'].map(inq_levels)

# %%
inq_prop = pd.DataFrame({'Count':loan['inq_last_6mths'].value_counts(),
                       'Proportion(%)':round(loan['inq_last_6mths'].value_counts(normalize=True)*100, 2)})
inq_prop
# Out:
#        Count  Proportion(%)
# No    130654          61.36
# Low    73800          34.66
# High    8463           3.97

# %%
fig, ax = plt.subplots(figsize=(10,5))
inq_prop.plot(kind='bar', y='Count', ax=ax)
plt.xlabel('Inquiries in 6 Months', fontsize = 13)
plt.ylabel('Frequency (Count)', fontsize = 13)
plt.yticks()
plt.title('Distribution of Inquiries in 6 Months', fontsize=14, fontweight=550)
plt.xticks(rotation = 'horizontal')
plt.legend('')

for x,y in enumerate(inq_prop['Count']):
    inq_value = inq_prop.index[x]
    plt.text(x, y+1500, inq_prop['Proportion(%)'].loc[inq_value], horizontalalignment='center', fontweight=700)

plt.show()

# %% [markdown]
# **Inference:**
# - The dataset seems to have imbalanced class distribution with -
#         ~61% - No Inquiries
#         ~35% - Low risk level Inquiries
#         ~4%  - High risk level Inquiries
# It still looks good for the purpose of this analysis as the frequency (counts) values are not small.
#
# **Actions:**
# - No action.

# %% [markdown]
# 7) Analysis of `home_ownership` : **The home ownership status provided by the borrower during registration or obtained from the credit report** column-

# %%
loan['home_ownership'].value_counts()
# Out:
# MORTGAGE    105961
# RENT         83425
# OWN          23529
# ANY              2
# Name: home_ownership, dtype: int64

# %%
loan[loan['home_ownership']=='ANY']
# Out:
#         funded_amnt  term  int_rate  installment grade home_ownership  \
# 20663         34300     1     14.48      1180.31     C            ANY
# 190593        24000     2     16.55       590.68     D            ANY
#
#         annual_inc loan_status    dti delinq_2yrs  earliest_cr_line  \
# 20663      78000.0     Current  17.71       Clean              1978
# 190593     77500.0     Current  34.05       Clean              2004
#
#        inq_last_6mths  open_acc pub_rec  revol_bal  revol_util  out_prncp  \
# 20663              No        10      No      26312        42.6    34300.0
# 190593           Low         13      No       7151        34.5    22387.2
#
#         total_pymnt  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 20663          0.00              0.0           0.00                 0.0
# 190593      3499.95           1612.8        1887.15                 0.0
#
#        recoveries collection_recovery_fee  last_pymnt_amnt acc_now_delinq  \
# 20663          No                      No             0.00             No
# 190593         No                      No           590.68             No
#
#         tot_coll_amt  tot_cur_bal  total_rev_hi_lim
# 20663              0       319768             86000
# 190593             0        91938             20700

# %%
loan = loan.drop(loan[loan['home_ownership'] == 'ANY'].index)

# %%
loan['home_ownership'].value_counts()
# Out:
# MORTGAGE    105961
# RENT         83425
# OWN          23529
# Name: home_ownership, dtype: int64

# %%
ho_prop = pd.DataFrame({'Count':loan['home_ownership'].value_counts(),
                       'Proportion(%)':round(loan['home_ownership'].value_counts(normalize=True)*100, 2)})
ho_prop
# Out:
#            Count  Proportion(%)
# MORTGAGE  105961          49.77
# RENT       83425          39.18
# OWN        23529          11.05

# %%
fig, ax = plt.subplots(figsize=(10,5))
ho_prop.plot(kind='bar', y='Count', ax=ax)
plt.xlabel('Home Ownership', fontsize = 13)
plt.ylabel('Frequency (Count)', fontsize = 13)
plt.yticks()
plt.title('Distribution of Home Ownership', fontsize=14, fontweight=550)
plt.xticks(rotation = 'horizontal')
plt.legend('')

for x,y in enumerate(ho_prop['Count']):
    ho_value = ho_prop.index[x]
    plt.text(x, y+1500, ho_prop['Proportion(%)'].loc[ho_value], horizontalalignment='center', fontweight=700)

plt.show()

# %% [markdown]
# **Inference:**
# - The dataset seems to have slightly imbalanced class distribution with -
#         ~50% - Mortgage Homes
#         ~39% - Rented Homes
#         ~11% - Own Homes
# It still looks good for the purpose of this analysis as the frequency (counts) values are not small.
#
# **Actions:**
# - No action.

# %%
loan.head()
# Out:
#    funded_amnt  term  int_rate  installment grade home_ownership  annual_inc  \
# 0        20000     1     12.29       667.06     C            OWN     65000.0
# 1        11000     1     12.69       369.00     C       MORTGAGE     40000.0
# 2         7000     1      9.99       225.84     B       MORTGAGE     32000.0
# 3        10000     1     10.99       327.34     B       MORTGAGE     48000.0
# 4         9550     1     19.99       354.87     E           RENT     32376.0
#
#    loan_status    dti delinq_2yrs  earliest_cr_line inq_last_6mths  open_acc  \
# 0  Charged Off  20.72       Clean              2000           Low         25
# 1  Charged Off  24.57       Clean              2002             No        13
# 2  Charged Off  32.41       Clean              2006           Low         18
# 3  Charged Off  30.98       Clean              1999           Low         18
# 4  Charged Off  32.54       Clean              1999           High         9
#
#   pub_rec  revol_bal  revol_util  out_prncp  total_pymnt  total_rec_prncp  \
# 0      No      31578        77.0        0.0         0.00             0.00
# 1     Yes       5084        38.8        0.0     10043.49          9942.67
# 2      No      12070        74.0        0.0       221.96           167.56
# 3      No      22950        66.0        0.0       315.13           235.76
# 4      No       4172        29.6        0.0       333.66           195.78
#
#    total_rec_int  total_rec_late_fee recoveries collection_recovery_fee  \
# 0           0.00                 0.0         No                      No
# 1         100.81                 0.0         No                      No
# 2          54.40                 0.0         No                      No
# 3          79.37                 0.0         No                      No
# 4         137.88                 0.0         No                      No
#
#    last_pymnt_amnt acc_now_delinq  tot_coll_amt  tot_cur_bal  total_rev_hi_lim
# 0             0.00             No             0        52303             41000
# 1         10059.00             No           332       175731             13100
# 2           225.84             No             0       202012             16300
# 3           327.34             No             0       108235             34750
# 4           354.87             No             0        45492             14100

# %%
loan.drop(columns=['recoveries','collection_recovery_fee','acc_now_delinq'], inplace=True)

# %%
loan.shape
# Out:
# (212915, 25)

# %% [markdown]
# **Interpretation:**
#
# Based on above analysis we droped redundant features - `recoveries`, `collection_recovery_fee`, `acc_now_delinq`.

# %%
# final dataset for further analysis

loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 212915 entries, 0 to 212998
# Data columns (total 25 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   funded_amnt         212915 non-null  int64
#  1   term                212915 non-null  int32
#  2   int_rate            212915 non-null  float64
#  3   installment         212915 non-null  float64
#  4   grade               212915 non-null  object
#  5   home_ownership      212915 non-null  object
#  6   annual_inc          212915 non-null  float64
#  7   loan_status         212915 non-null  object
#  8   dti                 212915 non-null  float64
#  9   delinq_2yrs         212915 non-null  object
#  10  earliest_cr_line    212915 non-null  int32
#  11  inq_last_6mths      212915 non-null  object
#  12  open_acc            212915 non-null  int64
#  13  pub_rec             212915 non-null  object
#  14  revol_bal           212915 non-null  int64
#  15  revol_util          212915 non-null  float64
#  16  out_prncp           212915 non-null  float64
#  17  total_pymnt         212915 non-null  float64
#  18  total_rec_prncp     212915 non-null  float64
#  19  total_rec_int       212915 non-null  float64
#  20  total_rec_late_fee  212915 non-null  float64
#  21  last_pymnt_amnt     212915 non-null  float64
#  22  tot_coll_amt        212915 non-null  int64
#  23  tot_cur_bal         212915 non-null  int64
#  24  total_rev_hi_lim    212915 non-null  int64
# dtypes: float64(11), int32(2), int64(6), object(6)
# memory usage: 40.6+ MB

# %% [markdown]
# ### Univariate Analysis:
# #### 1. Univariate Anlysis for Categorical Features -

# %%
loan_cat = loan.select_dtypes(object)
loan_cat.head()
# Out:
#   grade home_ownership  loan_status delinq_2yrs inq_last_6mths pub_rec
# 0     C            OWN  Charged Off       Clean           Low       No
# 1     C       MORTGAGE  Charged Off       Clean             No     Yes
# 2     B       MORTGAGE  Charged Off       Clean           Low       No
# 3     B       MORTGAGE  Charged Off       Clean           Low       No
# 4     E           RENT  Charged Off       Clean           High      No

# %%
loan_cat.describe().T
# Out:
#                  count unique       top    freq
# grade           212915      7         B   62645
# home_ownership  212915      3  MORTGAGE  105961
# loan_status     212915      2   Current  210142
# delinq_2yrs     212915      4     Clean  168746
# inq_last_6mths  212915      3        No  130653
# pub_rec         212915      2        No  175239

# %%
plot_cat_col = ['grade','home_ownership','delinq_2yrs','inq_last_6mths','pub_rec']

plt.figure(figsize=(15,35))
count = 1

for i in plot_cat_col:
    ax = plt.subplot(8,2,count)
    sns.countplot(x=i, data=loan)
    plt.title(i)
    plt.xticks(rotation=0)
    
    for p in ax.patches:
        ax.annotate(p.get_height(), (p.get_x()+0.2, p.get_height()+100))
        
    count += 1
        
plt.tight_layout()
plt.show()

# %% [markdown]
# **Inference:**
# - `grade` : Here, almost 90% of the borrowers credit score is A, B, C and D which means maximum borrowers have good credit history.
# - `home_ownership` : Here, almost 50% of the borrowers have taken loan by MORTGAGING their property to the lending institution (bank), 39% of the borrowers have RENTED properties and only 11% of the borrowers taking loan have their OWN properties which means maximum borrowers applying for loan can be assumed from middle class category.
# - `delinq_2yrs` : Here, the best part is only 0.8% of the borrowers are at Severe risk level since they have done maximum late installment payment in past 2 years, which means most of the borrowers are regular payers.
# - `inq_last_6mnths` : Here we can infer that only 4% of the borrowers are at High risk level for funding loan amount, since they have inquired about loan multiple times in past 6 months, which means they're the borrowers who are highly risky for lending loan by financial institutions.
# - `pub_rec` : Here almost 18% of the borrowers have derogatory public records due to multiple reasons which means they can have a lasting impact on credit scores and can be highly risky for financial institutions.

# %% [markdown]
# #### 2. Univariate Analysis for Target Feature -

# %%
plt.figure(figsize=(5,5))
loan_status = loan['loan_status'].value_counts()
plt.pie(loan_status, autopct='%.2f%%', labels=loan_status.index, 
        colors=['#77BFE2','tomato'], wedgeprops={'edgecolor':'white'}, explode=[0,0.2])
plt.title('Loan Status')
plt.show()

# %% [markdown]
# **Inference:**
# - Data is highly imbalanced since 99% of the data falls under 'Current' (Non-Defaulters) and only 1% of the data falls under 'Charged-Off' (Defaulters) sub-category.
#
# **Actions:**
# - Balancing the data during train-test-split data preprocessing.

# %% [markdown]
# #### 3. Univariate Analysis for Numeric Features -

# %%
loan_num = loan.select_dtypes(np.number)
loan_num.head()
# Out:
#    funded_amnt  term  int_rate  installment  annual_inc    dti  \
# 0        20000     1     12.29       667.06     65000.0  20.72
# 1        11000     1     12.69       369.00     40000.0  24.57
# 2         7000     1      9.99       225.84     32000.0  32.41
# 3        10000     1     10.99       327.34     48000.0  30.98
# 4         9550     1     19.99       354.87     32376.0  32.54
#
#    earliest_cr_line  open_acc  revol_bal  revol_util  out_prncp  total_pymnt  \
# 0              2000        25      31578        77.0        0.0         0.00
# 1              2002        13       5084        38.8        0.0     10043.49
# 2              2006        18      12070        74.0        0.0       221.96
# 3              1999        18      22950        66.0        0.0       315.13
# 4              1999         9       4172        29.6        0.0       333.66
#
#    total_rec_prncp  total_rec_int  total_rec_late_fee  last_pymnt_amnt  \
# 0             0.00           0.00                 0.0             0.00
# 1          9942.67         100.81                 0.0         10059.00
# 2           167.56          54.40                 0.0           225.84
# 3           235.76          79.37                 0.0           327.34
# 4           195.78         137.88                 0.0           354.87
#
#    tot_coll_amt  tot_cur_bal  total_rev_hi_lim
# 0             0        52303             41000
# 1           332       175731             13100
# 2             0       202012             16300
# 3             0       108235             34750
# 4             0        45492             14100

# %%
loan_num.describe().T
# Out:
#                        count           mean            std      min  \
# funded_amnt         212915.0   15258.578423    8611.159978  1000.00
# term                212915.0       1.328516       0.469675     1.00
# int_rate            212915.0      12.400531       4.248994     5.32
# installment         212915.0     440.847182     245.831980    30.12
# annual_inc          212915.0   77792.383989   81878.119287     0.00
# dti                 212915.0      19.361800      31.931633     0.00
# earliest_cr_line    212915.0    1998.344297       7.643759  1950.00
# open_acc            212915.0      11.977414       5.662891     1.00
# revol_bal           212915.0   17989.681671   24571.451730     0.00
# revol_util          212915.0      53.343395      23.903572     0.00
# out_prncp           212915.0   14182.101105    8347.468697     0.00
# total_pymnt         212915.0    1364.125827    1301.889065     0.00
# total_rec_prncp     212915.0     891.471816     996.998197     0.00
# total_rec_int       212915.0     468.130643     479.847826     0.00
# total_rec_late_fee  212915.0       0.047184       1.230852     0.00
# last_pymnt_amnt     212915.0     436.177583     450.725676     0.00
# tot_coll_amt        212915.0     262.042411    2215.618841     0.00
# tot_cur_bal         212915.0  141622.785661  156821.509119     0.00
# total_rev_hi_lim    212915.0   34451.013137   35300.919688     0.00
#
#                           25%       50%        75%         max
# funded_amnt          8500.000  14000.00   20000.00    35000.00
# term                    1.000      1.00       2.00        2.00
# int_rate                9.170     12.29      14.65       28.99
# installment           262.230    382.87     578.79     1445.46
# annual_inc          47000.000  65000.00   92500.00  9000000.00
# dti                    12.660     18.72      25.52     9999.00
# earliest_cr_line     1994.000   2000.00    2004.00     2012.00
# open_acc                8.000     11.00      15.00       82.00
# revol_bal            6549.000  12063.00   21591.00  1630818.00
# revol_util             35.500     53.50      71.70      193.00
# out_prncp            7653.725  12824.81   19494.53    49372.86
# total_pymnt           507.480   1029.37    1859.63    35773.70
# total_rec_prncp       328.290    656.92    1165.99    34963.28
# total_rec_int         142.920    310.89     631.08     4722.36
# total_rec_late_fee      0.000      0.00       0.00      124.76
# last_pymnt_amnt       250.070    375.43     572.61    35330.49
# tot_coll_amt            0.000      0.00       0.00   380757.00
# tot_cur_bal         31430.500  81376.00  209681.50  4127799.00
# total_rev_hi_lim    14600.000  25100.00   42600.00  1641300.00

# %%
plot_num_col = ['funded_amnt','term','int_rate','installment','annual_inc','dti','earliest_cr_line','open_acc','revol_bal','revol_util',
                'out_prncp','total_pymnt','total_rec_prncp','total_rec_int','total_rec_late_fee','last_pymnt_amnt','tot_coll_amt','tot_cur_bal','total_rev_hi_lim']

means = []
medians = []
modes = []
skewness = []
kurtosis = []

for i in plot_num_col:
    means.append(loan_num[i].mean())
    medians.append(loan_num[i].median())
    modes.append(loan_num[i].mode()[0])
    skewness.append(loan_num[i].skew())
    kurtosis.append(loan_num[i].kurt())
    
pd.DataFrame({'Mean' : means,
             'Median': medians,
             'Mode': modes,
             'Skewness':skewness,
             'Kurtosis':kurtosis}, index=plot_num_col)
# Out:
#                              Mean    Median      Mode    Skewness  \
# funded_amnt          15258.578423  14000.00  10000.00    0.617480
# term                     1.328516      1.00      1.00    0.730231
# int_rate                12.400531     12.29      9.17    0.572952
# installment            440.847182    382.87    318.79    0.920148
# annual_inc           77792.383989  65000.00  60000.00   50.374503
# dti                     19.361800     18.72     18.00  286.984433
# earliest_cr_line      1998.344297   2000.00   2001.00   -1.045072
# open_acc                11.977414     11.00      9.00    1.269852
# revol_bal            17989.681671  12063.00      0.00    9.856943
# revol_util              53.343395     53.50      0.00   -0.055214
# out_prncp            14182.101105  12824.81      0.00    0.601303
# total_pymnt           1364.125827   1029.37      0.00    4.451270
# total_rec_prncp        891.471816    656.92      0.00    8.053342
# total_rec_int          468.130643    310.89      0.00    2.074264
# total_rec_late_fee       0.047184      0.00      0.00   35.416237
# last_pymnt_amnt        436.177583    375.43      0.00   29.048814
# tot_coll_amt           262.042411      0.00      0.00   48.927391
# tot_cur_bal         141622.785661  81376.00      0.00    2.896175
# total_rev_hi_lim     34451.013137  25100.00  13000.00    5.707599
#
#                         Kurtosis
# funded_amnt            -0.402565
# term                   -1.466776
# int_rate                0.167218
# installment             0.556999
# annual_inc           4473.474168
# dti                 89625.503154
# earliest_cr_line        1.503243
# open_acc                3.044119
# revol_bal             240.530886
# revol_util             -0.754090
# out_prncp              -0.368754
# total_pymnt            58.837253
# total_rec_prncp       153.779099
# total_rec_int           5.729375
# total_rec_late_fee   1684.255599
# last_pymnt_amnt      1517.810863
# tot_coll_amt         5682.837143
# tot_cur_bal            22.225367
# total_rev_hi_lim       85.300903

# %% [markdown]
# **Inference:**
# - We can find the below details for all the numeric columns:
#     - Mean value
#     - Median value
#     - Mode value
#     - Skewness value
#     - Kurtosis value

# %%
plot_num_col = ['funded_amnt','term','int_rate','installment','annual_inc','dti','earliest_cr_line','open_acc','revol_bal','revol_util',
                'out_prncp','total_pymnt','total_rec_prncp','total_rec_int','total_rec_late_fee','last_pymnt_amnt','tot_coll_amt','tot_cur_bal','total_rev_hi_lim']

plt.figure(figsize=(15,35))
count = 1

for i in plot_num_col:
    ax = plt.subplot(8,3,count)
    sns.histplot(x=loan_num[i], kde=True)
    
    plt.axvline(loan_num[i].mean(), color='b')
    plt.axvline(loan_num[i].median(), color='r')
    plt.axvline(loan_num[i].mode()[0], color='g')
    
    plt.title(i)
    plt.xticks(rotation=0)
    
    count +=1
    
plt.tight_layout()   
plt.show()

# %% [markdown]
# ### Bivariate Analysis:

# %%
palette = {'grade': sns.color_palette('husl')[1:3], 
           'home_ownership': sns.color_palette('muted')[2:4], 
           'delinq_2yrs': sns.color_palette('bright')[8:], 
           'inq_last_6mths': sns.color_palette('husl')[4:6],  
           'pub_rec': sns.color_palette('Dark2')[0:2]}

plt.figure(figsize=(15,50))
count = 1

for i in plot_cat_col:
    ax = plt.subplot(8, 2, count)
    sns.countplot(x=loan[i],hue=loan['loan_status'],palette=palette[i])
    plt.title(i)
    plt.xticks(rotation=0)
    
    for p in ax.patches:
        ax.annotate(p.get_height(), (p.get_x() + 0.1, p.get_height() + 100))
    
    count += 1
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Multivariate Analysis:
#
# 1) Funded Amount based on Grade and Loan Status

# %%
loan.groupby(['grade','loan_status'])['funded_amnt'].sum()
# Out:
# grade  loan_status
# A      Charged Off      1167725
#        Current        545996925
# B      Charged Off      4857150
#        Current        877046925
# C      Charged Off      9455125
#        Current        902725100
# D      Charged Off     10718425
#        Current        476008350
# E      Charged Off      9240800
#        Current        302063050
# F      Charged Off      5094275
#        Current         86527300
# G      Charged Off      1425375
#        Current         16453700
# Name: funded_amnt, dtype: int64

# %%
ax = sns.barplot(x=loan['grade'], y=loan['funded_amnt'], dodge=False, hue=loan['loan_status'], hue_order=['Charged Off','Current'])

ax.set_xlabel('Grade')
ax.set_ylabel('Funded Loan Amount')
ax.set_title('Funded Amount by Grade and Loan Status')
plt.show()

# %% [markdown]
# 2) Funded Amount based on Home Ownership and Loan Status

# %%
loan.groupby(['home_ownership','loan_status'])['funded_amnt'].sum()
# Out:
# home_ownership  loan_status
# MORTGAGE        Charged Off      18389400
#                 Current        1757499725
# OWN             Charged Off       4237425
#                 Current         348956500
# RENT            Charged Off      19332050
#                 Current        1100365125
# Name: funded_amnt, dtype: int64

# %%
ax = sns.barplot(x=loan['home_ownership'], y=loan['funded_amnt'], dodge=False, hue=loan['loan_status'], hue_order=['Charged Off','Current'])

ax.set_xlabel('Home Ownership')
ax.set_ylabel('Funded Loan Amount')
ax.set_title('Funded Amount by Home Ownership and Loan Status')
plt.show()

# %% [markdown]
# 3) Funded Amount based on No. of Public Records and Loan Status

# %%
loan.groupby(['pub_rec','loan_status'])['funded_amnt'].sum()
# Out:
# pub_rec  loan_status
# No       Charged Off      34521650
#          Current        2725693175
# Yes      Charged Off       7437225
#          Current         481128175
# Name: funded_amnt, dtype: int64

# %%
ax = sns.barplot(x=loan['pub_rec'], y=loan['funded_amnt'], dodge=False, hue=loan['loan_status'], hue_order=['Charged Off','Current'])

ax.set_xlabel('Have Public Records')
ax.set_ylabel('Funded Loan Amount')
ax.set_title('Funded Amount by Have Public Records and Loan Status')
plt.show()

# %% [markdown]
# 4) Funded Amount based on Delinquencies (2 years) and Loan Status

# %%
loan.groupby(['delinq_2yrs','loan_status'])['funded_amnt'].sum()
# Out:
# delinq_2yrs  loan_status
# Clean        Charged Off      33336050
#              Current        2543766075
# Early Stage  Charged Off       7260700
#              Current         570009450
# Moderate     Charged Off       1080350
#              Current          68492750
# Severe       Charged Off        281775
#              Current          24553075
# Name: funded_amnt, dtype: int64

# %%
ax = sns.barplot(x=loan['delinq_2yrs'], y=loan['funded_amnt'], dodge=False, hue=loan['loan_status'], hue_order=['Charged Off','Current'])

ax.set_xlabel('Delinquencies (2 years)')
ax.set_ylabel('Funded Loan Amount')
ax.set_title('Funded Amount by Delinquencies (2 years) and Loan Status')
plt.show()

# %% [markdown]
# #### Independant Numerical Features Correlation

# %%
plt.figure(figsize=(20,11))

mask = np.triu(np.ones_like(loan.corr()))
sns.heatmap(loan.corr(), mask=mask, annot=True, cmap='YlGnBu')
plt.show()

# %% [markdown]
# ### Data Preprocessing:
#
# #### Split the data into train-test-split -
# - Split the dataset into target and feature.
# - Split the target and feature for training and testing (final validation) models.

# %%
loan.shape
# Out:
# (212915, 25)

# %%
loan.head()
# Out:
#    funded_amnt  term  int_rate  installment grade home_ownership  annual_inc  \
# 0        20000     1     12.29       667.06     C            OWN     65000.0
# 1        11000     1     12.69       369.00     C       MORTGAGE     40000.0
# 2         7000     1      9.99       225.84     B       MORTGAGE     32000.0
# 3        10000     1     10.99       327.34     B       MORTGAGE     48000.0
# 4         9550     1     19.99       354.87     E           RENT     32376.0
#
#    loan_status    dti delinq_2yrs  earliest_cr_line inq_last_6mths  open_acc  \
# 0  Charged Off  20.72       Clean              2000           Low         25
# 1  Charged Off  24.57       Clean              2002             No        13
# 2  Charged Off  32.41       Clean              2006           Low         18
# 3  Charged Off  30.98       Clean              1999           Low         18
# 4  Charged Off  32.54       Clean              1999           High         9
#
#   pub_rec  revol_bal  revol_util  out_prncp  total_pymnt  total_rec_prncp  \
# 0      No      31578        77.0        0.0         0.00             0.00
# 1     Yes       5084        38.8        0.0     10043.49          9942.67
# 2      No      12070        74.0        0.0       221.96           167.56
# 3      No      22950        66.0        0.0       315.13           235.76
# 4      No       4172        29.6        0.0       333.66           195.78
#
#    total_rec_int  total_rec_late_fee  last_pymnt_amnt  tot_coll_amt  \
# 0           0.00                 0.0             0.00             0
# 1         100.81                 0.0         10059.00           332
# 2          54.40                 0.0           225.84             0
# 3          79.37                 0.0           327.34             0
# 4         137.88                 0.0           354.87             0
#
#    tot_cur_bal  total_rev_hi_lim
# 0        52303             41000
# 1       175731             13100
# 2       202012             16300
# 3       108235             34750
# 4        45492             14100

# %%
y = loan['loan_status']       # target
X = loan.drop('loan_status', axis=1)

# Display target and feature
print('Target: ')
display(y.head())
print('\nFeatures: ')
display(X.head())
# Out:
# Target:
# 0    Charged Off
# 1    Charged Off
# 2    Charged Off
# 3    Charged Off
# 4    Charged Off
# Name: loan_status, dtype: object
# Features:
#    funded_amnt  term  int_rate  installment grade home_ownership  annual_inc  \
# 0        20000     1     12.29       667.06     C            OWN     65000.0
# 1        11000     1     12.69       369.00     C       MORTGAGE     40000.0
# 2         7000     1      9.99       225.84     B       MORTGAGE     32000.0
# 3        10000     1     10.99       327.34     B       MORTGAGE     48000.0
# 4         9550     1     19.99       354.87     E           RENT     32376.0
#
#      dti delinq_2yrs  earliest_cr_line inq_last_6mths  open_acc pub_rec  \
# 0  20.72       Clean              2000           Low         25      No
# 1  24.57       Clean              2002             No        13     Yes
# 2  32.41       Clean              2006           Low         18      No
# 3  30.98       Clean              1999           Low         18      No
# 4  32.54       Clean              1999           High         9      No
#
#    revol_bal  revol_util  out_prncp  total_pymnt  total_rec_prncp  \
# 0      31578        77.0        0.0         0.00             0.00
# 1       5084        38.8        0.0     10043.49          9942.67
# 2      12070        74.0        0.0       221.96           167.56
# 3      22950        66.0        0.0       315.13           235.76
# 4       4172        29.6        0.0       333.66           195.78
#
#    total_rec_int  total_rec_late_fee  last_pymnt_amnt  tot_coll_amt  \
# 0           0.00                 0.0             0.00             0
# 1         100.81                 0.0         10059.00           332
# 2          54.40                 0.0           225.84             0
# 3          79.37                 0.0           327.34             0
# 4         137.88                 0.0           354.87             0
#
#    tot_cur_bal  total_rev_hi_lim
# 0        52303             41000
# 1       175731             13100
# 2       202012             16300
# 3       108235             34750
# 4        45492             14100

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.3, random_state=42)

print(f'Shape of X_train: {X_train.shape}\nShape of y_train: {y_train.shape}',
      f'\n\nShape of X_test: {X_test.shape}\nShape of y_test: {y_test.shape}')
# Out:
# Shape of X_train: (149040, 24)
# Shape of y_train: (149040,)
#
# Shape of X_test: (63875, 24)
# Shape of y_test: (63875,)
